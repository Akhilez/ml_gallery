# %%
from lib.mnist_aug.mnist_augmenter import DataManager, MNISTAug

# %%
aug = MNISTAug()
dm = DataManager()
dm.load_test()

# %%
aug.max_objects = 5
aug.min_objects = 3

x, y = aug.get_augmented(dm.x_test, dm.y_test, 1, get_captions=True)

[print(yi['class']) for yi in y[0]]

for i in range(len(x)):
    DataManager.plot_num(x[i], y[i])
    DataManager.plot_num(x[i])
# Out:
# 7 is in this box
# this region has a 5
# this box contains a 4
# this region consists 1
# seven and 5 are nearby
# 4 lies close to 1
# /Users/akhildevarashetti/code/ml_gallery/ml_py/lib/mnist_aug/mnist_augmenter.py:354: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
