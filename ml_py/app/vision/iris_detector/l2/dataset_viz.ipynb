# %%
from settings import BASE_DIR
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import itertools
import copy

# %%
image = Image.open(f'{BASE_DIR}/data/pupil/L2/training_set/images/000008372_Ycrop_Hres_L.png')

# %%
plt.imshow(image)

# %%
mask = Image.open(f'{BASE_DIR}/data/pupil/L2/training_set/masks/000008372_Ycrop_Hres_L.png')

# %%
plt.imshow(mask, cmap='gray')

# %%
mask = np.array(mask)

# %%
mask_zeros = copy.deepcopy(mask)
mask_zeros[mask == 0] = 1
mask_zeros[mask != 0] = 0
plt.imshow(mask_zeros, cmap='gray')

# %%
mask_zeros = copy.deepcopy(mask)
mask_zeros[mask == 1] = 1
mask_zeros[mask != 1] = 0
plt.imshow(mask_zeros, cmap='gray')

# %%
mask_zeros = copy.deepcopy(mask)
mask_zeros[mask == 2] = 1
mask_zeros[mask != 2] = 0
plt.imshow(mask_zeros, cmap='gray')

# %%
mask[mask == 0].shape

# %%
values = [112.0000,80.0000,10.5230,10.5230,0.0000,110.0000,78.0000,38.0270,37.5450,33.7830]

# %%
plt.imshow(mask, cmap='gray')
plt.scatter([112.0000], [80.0000])
plt.gca().add_patch(Ellipse(xy=(values[0], values[1]), width=2*values[2], height=2*values[3], angle=values[4], color='r', fill=False))
plt.gca().add_patch(Ellipse(xy=(values[5], values[6]), width=2*values[7], height=2*values[8], angle=values[4], color='blue', fill=False))

# %%
plt.imshow(image)
plt.scatter([112.0000], [80.0000])
plt.gca().add_patch(Ellipse(xy=(values[0], values[1]), width=2*values[2], height=2*values[3], angle=values[4], color='r', fill=False))
plt.gca().add_patch(Ellipse(xy=(values[5], values[6]), width=2*values[7], height=2*values[8], angle=values[4], color='blue', fill=False))
